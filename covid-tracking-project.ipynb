# %% [markdown]
# <a href="https://colab.research.google.com/github/mimiflynn/covid-data/blob/master/covid-tracking-project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://covidtracking.com/api

# %%
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import requests as request
import pandas as pd
import numpy as np

# %%
current_states = request.get('https://covidtracking.com/api/v1/states/current.json')
current_states_daily = request.get('https://covidtracking.com/api/v1/states/daily.json')
current_us = request.get('https://covidtracking.com/api/v1/us/current.json')

# %%
states = pd.DataFrame.from_dict(current_states.json())
states_daily = pd.DataFrame.from_dict(current_states_daily.json())
us = pd.DataFrame.from_dict(current_us.json())

# %%
states_daily
# Out:
#           date state  ...  positiveIncrease  totalTestResultsIncrease
# 0     20200420    AK  ...               2.0                     229.0
# 1     20200420    AL  ...             188.0                     188.0
# 2     20200420    AR  ...             142.0                    2344.0
# 3     20200420    AS  ...               0.0                       0.0
# 4     20200420    AZ  ...             135.0                    1510.0
# ...        ...   ...  ...               ...                       ...
# 2559  20200301    MI  ...               NaN                       NaN
# 2560  20200301    RI  ...               NaN                       NaN
# 2561  20200301    WA  ...              12.0                      12.0
# 2562  20200229    WA  ...               9.0                       9.0
# 2563  20200228    WA  ...               NaN                       NaN
#
# [2564 rows x 25 columns]

# %%
ny_daily = states_daily.loc[states_daily['state'] == 'NY']

# %%
ny_daily
# Out:
#           date state  ...  positiveIncrease  totalTestResultsIncrease
# 37    20200420    NY  ...            4726.0                   16306.0
# 93    20200419    NY  ...            6054.0                   21023.0
# 149   20200418    NY  ...            7090.0                   23309.0
# 205   20200417    NY  ...            7358.0                   22644.0
# 261   20200416    NY  ...            8505.0                   24567.0
# 317   20200415    NY  ...           11571.0                   26869.0
# 373   20200414    NY  ...            7177.0                   20786.0
# 429   20200413    NY  ...            6337.0                   16756.0
# 485   20200412    NY  ...            8236.0                   20621.0
# 541   20200411    NY  ...            9946.0                   23095.0
# 597   20200410    NY  ...           10575.0                   26336.0
# 653   20200409    NY  ...           10621.0                   26396.0
# 709   20200408    NY  ...           10453.0                   25095.0
# 765   20200407    NY  ...            8174.0                   19247.0
# 821   20200406    NY  ...            8658.0                   18531.0
# 877   20200405    NY  ...            8327.0                   18659.0
# 933   20200404    NY  ...           10841.0                   23101.0
# 989   20200403    NY  ...           10482.0                   21555.0
# 1045  20200402    NY  ...            8669.0                   18085.0
# 1101  20200401    NY  ...            7917.0                   15694.0
# 1157  20200331    NY  ...            9298.0                   18718.0
# 1213  20200330    NY  ...            6984.0                   14108.0
# 1269  20200329    NY  ...            7195.0                   16426.0
# 1325  20200328    NY  ...            7683.0                   10181.0
# 1381  20200327    NY  ...            7377.0                   23649.0
# 1437  20200326    NY  ...            6447.0                   18625.0
# 1493  20200325    NY  ...            5146.0                   12209.0
# 1549  20200324    NY  ...            4790.0                   12981.0
# 1605  20200323    NY  ...            5707.0                   16888.0
# 1661  20200322    NY  ...            4812.0                   15964.0
# 1717  20200321    NY  ...            3254.0                   13010.0
# 1773  20200320    NY  ...            2950.0                   10143.0
# 1829  20200319    NY  ...            1770.0                    7687.0
# 1885  20200318    NY  ...             682.0                    7391.0
# 1941  20200317    NY  ...             750.0                    1713.0
# 1997  20200316    NY  ...             221.0                     221.0
# 2050  20200315    NY  ...             205.0                    1969.0
# 2101  20200314    NY  ...             103.0                     103.0
# 2152  20200313    NY  ...             205.0                    2892.0
# 2203  20200312    NY  ...               0.0                       0.0
# 2254  20200311    NY  ...              43.0                      43.0
# 2305  20200310    NY  ...              31.0                      31.0
# 2356  20200309    NY  ...              37.0                      37.0
# 2407  20200308    NY  ...              29.0                      29.0
# 2458  20200307    NY  ...              43.0                      43.0
# 2499  20200306    NY  ...              11.0                      27.0
# 2527  20200305    NY  ...              16.0                      44.0
# 2546  20200304    NY  ...               NaN                       NaN
#
# [48 rows x 25 columns]

# %%
ny_daily.plot(x='date', y='positive', kind='bar')
