# %% [markdown]
# <a href="https://colab.research.google.com/github/mimiflynn/covid-data/blob/master/covid_nyt_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
from datetime import timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.close('all')
plt.xkcd()

# %%
today = datetime.today()
print('Last run at:')
print(today)
# Out:
# Last run at:
# 2020-05-11 19:02:48.606569

# %%
# https://github.com/nytimes/covid-19-data
states = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')

# %%
states
# Out:
#             date          state  fips  cases  deaths
# 0     2020-01-21     Washington    53      1       0
# 1     2020-01-22     Washington    53      1       0
# 2     2020-01-23     Washington    53      1       0
# 3     2020-01-24       Illinois    17      1       0
# 4     2020-01-24     Washington    53      1       0
# ...          ...            ...   ...    ...     ...
# 3804  2020-05-10       Virginia    51  24081     839
# 3805  2020-05-10     Washington    53  17909     939
# 3806  2020-05-10  West Virginia    54   1362      54
# 3807  2020-05-10      Wisconsin    55  10219     400
# 3808  2020-05-10        Wyoming    56    662       7
#
# [3809 rows x 5 columns]

# %%
ny = states.loc[states['state'] == 'New York']

ny.plot(x='date', y='cases', kind='bar', figsize=(15,15))
ny.plot(x='date', y='deaths', kind='bar', figsize=(15,15))

# %%
tx = states.loc[states['state'] == 'Texas']
tx.plot(x='date', y='cases', kind='bar', figsize=(15,15))
tx.plot(x='date', y='deaths', kind='bar', figsize=(15,15))

# %%
co = states.loc[states['state'] == 'Colorado']
co.plot(x='date', y='cases', kind='bar', figsize=(15,15))
co.plot(x='date', y='deaths', kind='bar', figsize=(15,15))
